# %% [markdown]
# Week 6 Mini-project
# by Jeff Puuri
# for EdX course DSE200x - Python for Data Science
#
# References:
# Slide Template: https://docs.google.com/presentation/d/1CAXnIH7ctHePs-TVeWVKafB9c1-mxmdEKE8_ntzY_M0/edit#slide=id.g1e0c2d5179_0_5
# Mini-Project Description page: https://courses.edx.org/courses/course-v1:UCSanDiegoX+DSE200x+1T2018/courseware/82d46c5420924002ab6738f6c33aea53/77277bfa5b904ac79099930f7369dd18/1?activate_block_id=block-v1%3AUCSanDiegoX%2BDSE200x%2B1T2018%2Btype%40html%2Bblock%40a7c4de0902c3413abef80f135201c19c
#
# Data Exploration to figure out a project...
#
# Pick a dataset: I'm a GIS guy, so it needs to be world indicators
#
# Lots of variables, so find a couple to be of interest and value for a study

# %%
# Using NBs from wk 5, import the libraries we'll need
import pandas as pd
import numpy as np
#import random
import matplotlib.pyplot as plt
import folium

# %%
# Read in the data once injto a dataframe named df, it is a big dataset
df = pd.read_csv('D:/PjtData/4_PD/edX_DSE200x/wk5_Matplotlib/Indicators.csv')
#df = pd.read_csv('C:/PrjData/4_PD/DSE200x/wk5_Matplotlib/Indicators.csv')
df.shape
# Out:
# (5656458, 6)

# %%
# Here's the list of columns to use for future filters
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', 'Year',
#        'Value'],
#       dtype='object')

# %%
# Variables are going to be in the IndicatorName column, so look at what is available
# via .unique() which produces a numpy ndarray, so must cast back to pandas dataframe
# to export to excel so that I can see the list 
indicator_list = pd.DataFrame(df['IndicatorName'].unique())
type(indicator_list)
# Out:
# pandas.core.frame.DataFrame

# %%
# Send to Excel for interactive filter and sort tools to find interesting variables to study
# Comment this out once variable are decided because we don't need to regenerate the spreadsheet time after time,
# but leave it here so others can see the methodology and tools used during data exploration
#indicator_list.to_excel('D:/PjtData/4_PD/edX_DSE200x/wk5_Matplotlib/Indicators.xlsx', sheet_name='Indicators')

# %% [markdown]
# After review in Excel, going with:
# * Renewable internal freshwater resources per capita (cubic meters)
# * GDP per capita (current US\$), or maybe
# * Adjusted net national income per capita (current US$)
#
# Because it is reported there is a water crisis in developing countries,
# I would like to see the disparity in terms of: per capita GDP or income

# %%
h2oInd = 'Renewable internal freshwater resources per capita (cubic meters)'
incInd = 'Adjusted net national income per capita (current US$)'
dfh20 = df[df['IndicatorName'] == h2oInd]
dfinc = df[df['IndicatorName'] == incInd]
print(dfh20['Year'].min(), dfh20['Year'].max(), dfinc['Year'].min(), dfinc['Year'].max())
# Out:
# 1962 2013 1970 2013

# %%
yrMask = df['Year'] == 1972
h2oMask = df['IndicatorName'] == h2oInd
incMask = df['IndicatorName'] == incInd
#df[h2oMask].Year.unique().tolist()
#df[incMask].Year.unique().tolist()
set72h2o = df[(yrMask) & (h2oMask)]
set72inc = df[(yrMask) & (incMask)]
print(set72h2o.count(), set72inc.count())
# Out:
# CountryName      180
# CountryCode      180
# IndicatorName    180
# IndicatorCode    180
# Year             180
# Value            180
# dtype: int64 CountryName      129
# CountryCode      129
# IndicatorName    129
# IndicatorCode    129
# Year             129
# Value            129
# dtype: int64

# %%
set72 = set72h2o.merge(set72inc, on=['CountryCode'],how='left')
set72
# Out:
#                                       CountryName_x CountryCode  \
# 0                                        Arab World         ARB
# 1                            Caribbean small states         CSS
# 2                    Central Europe and the Baltics         CEB
# 3           East Asia & Pacific (all income levels)         EAS
# 4             East Asia & Pacific (developing only)         EAP
# 5                                         Euro area         EMU
# 6                                    European Union         EUU
# 7          Fragile and conflict affected situations         FCS
# 8            Heavily indebted poor countries (HIPC)         HPC
# 9                                       High income         HIC
# 10                                High income: OECD         OEC
# 11    Latin America & Caribbean (all income levels)         LCN
# 12      Latin America & Caribbean (developing only)         LAC
# 13     Least developed countries: UN classification         LDC
# 14                              Low & middle income         LMY
# 15                                       Low income         LIC
# 16                              Lower middle income         LMC
# 17   Middle East & North Africa (all income levels)         MEA
# 18     Middle East & North Africa (developing only)         MNA
# 19                                    Middle income         MIC
# 20                                    North America         NAC
# 21                                     OECD members         OED
# 22                               Other small states         OSS
# 23                                     Small states         SST
# 24                                       South Asia         SAS
# 25           Sub-Saharan Africa (all income levels)         SSF
# 26             Sub-Saharan Africa (developing only)         SSA
# 27                              Upper middle income         UMC
# 28                                            World         WLD
# 29                                      Afghanistan         AFG
# ..                                              ...         ...
# 150                                       Singapore         SGP
# 151                                 Solomon Islands         SLB
# 152                                         Somalia         SOM
# 153                                    South Africa         ZAF
# 154                                           Spain         ESP
# 155                                       Sri Lanka         LKA
# 156                             St. Kitts and Nevis         KNA
# 157                                           Sudan         SDN
# 158                                        Suriname         SUR
# 159                                       Swaziland         SWZ
# 160                                          Sweden         SWE
# 161                                     Switzerland         CHE
# 162                            Syrian Arab Republic         SYR
# 163                                        Tanzania         TZA
# 164                                        Thailand         THA
# 165                                     Timor-Leste         TMP
# 166                                            Togo         TGO
# 167                             Trinidad and Tobago         TTO
# 168                                         Tunisia         TUN
# 169                                          Turkey         TUR
# 170                                          Uganda         UGA
# 171                            United Arab Emirates         ARE
# 172                                  United Kingdom         GBR
# 173                                   United States         USA
# 174                                         Uruguay         URY
# 175                                   Venezuela, RB         VEN
# 176                                         Vietnam         VNM
# 177                                     Yemen, Rep.         YEM
# 178                                          Zambia         ZMB
# 179                                        Zimbabwe         ZWE
#
#                                        IndicatorName_x IndicatorCode_x  \
# 0    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 1    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 2    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 3    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 4    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 5    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 6    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 7    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 8    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 9    Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 10   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 11   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 12   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 13   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 14   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 15   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 16   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 17   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 18   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 19   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 20   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 21   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 22   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 23   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 24   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 25   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 26   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 27   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 28   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 29   Renewable internal freshwater resources per ca...  ER.H2O.INTR.PC
# 179    1972    2199.769186                                       Zimbabwe
#
#                                        IndicatorName_y    IndicatorCode_y  \
# 0                                                  NaN                NaN
# 1    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 2                                                  NaN                NaN
# 3    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 4    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 5    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 6    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 7                                                  NaN                NaN
# 8    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 9    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 10   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 11   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 12   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 13                                                 NaN                NaN
# 14   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 15                                                 NaN                NaN
# 16   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 17                                                 NaN                NaN
# 18                                                 NaN                NaN
# 19   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 20   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 21   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 22                                                 NaN                NaN
# 23   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 24   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 25   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 26   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 27   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 28   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 29   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# ..                                                 ...                ...
# 150                                                NaN                NaN
# 151  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 152                                                NaN                NaN
# 153  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 154  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 155  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 156                                                NaN                NaN
# 157                                                NaN                NaN
# 158  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 159  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 160  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 161                                                NaN                NaN
# 162  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 163                                                NaN                NaN
# 164  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 165                                                NaN                NaN
# 166  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 167  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 168  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 169  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 170  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 171                                                NaN                NaN
# 172  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 173  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 174  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 175  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 176                                                NaN                NaN
# 177                                                NaN                NaN
# 178  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 179  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
#
#      Year_y      Value_y
# 0       NaN          NaN
# 1    1972.0   805.715154
# 2       NaN          NaN
# 3    1972.0   362.267143
# 4    1972.0   115.433579
# 5    1972.0  2674.924799
# 6    1972.0  2280.283721
# 7       NaN          NaN
# 8    1972.0   157.243622
# 9    1972.0  2688.132428
# 10   1972.0  3171.254972
# 11   1972.0   648.562216
# 12   1972.0   537.595790
# 13      NaN          NaN
# 14   1972.0   177.059448
# 15      NaN          NaN
# 16   1972.0   129.227084
# 17      NaN          NaN
# 18      NaN          NaN
# 19   1972.0   182.227363
# 20   1972.0  5208.059855
# 21   1972.0  2915.404997
# 22      NaN          NaN
# 23   1972.0   473.388795
# 24   1972.0   113.974228
# 25   1972.0   212.986829
# 26   1972.0   211.717708
# 27   1972.0   232.806403
# 28   1972.0   856.407710
# 29   1972.0   129.198572
# ..      ...          ...
# 150     NaN          NaN
# 151  1972.0   135.965649
# 152     NaN          NaN
# 153  1972.0   753.636615
# 154  1972.0  1499.118071
# 155  1972.0   171.302640
# 156     NaN          NaN
# 157     NaN          NaN
# 158  1972.0   520.458538
# 159  1972.0   237.013716
# 160  1972.0  5296.020921
# 161     NaN          NaN
# 162  1972.0   440.284088
# 163     NaN          NaN
# 164  1972.0   183.860284
# 165     NaN          NaN
# 166  1972.0   130.896604
# 167  1972.0   838.665314
# 168  1972.0   377.262935
# 169  1972.0   522.496616
# 170  1972.0   130.476235
# 171     NaN          NaN
# 172  1972.0  2645.470213
# 173  1972.0  5301.269910
# 174  1972.0   711.072639
# 175  1972.0  1001.567385
# 176     NaN          NaN
# 177     NaN          NaN
# 178  1972.0   295.862225
# 179  1972.0   463.361550
#
# [180 rows x 11 columns]

# %%
set72notna = set72[set72['CountryName_y'].notna()]

# %%
plt.scatter(set72notna['Value_x'],set72notna['Value_y'])
